# %% [markdown]
# ## **Decision Trees**
#
#
# entropy
# p+: prob of 0
# p-: pron of 1
#
# h(c) is used to find whether it is pure(0) or impure(1) split
#
# h(c) = entropy
#
# entropy curve = bell shaped
# max value = 1 - impure split
# min value = 0 - pure split
#
# entropy range is between 0 to 1
#
#
# interview question: difference between entropy and gini index
#
#
#
# gini impurity
# max value 0.5 - impure split
# min value 0 - pure split
#
#
# which featurs to select the root of the decision tree - information gain

# %% [markdown]
# information gain
#
# helps us decide the feature to be the considered as the root of the decision tree
#
#
# higher gain - prefer to start from tht
#
#
#
# important question
# 1. when to use entropy and gini index
# - when ur dataset is small - use entropy
# - when ur dataset is large - use gini index
#
# all these were applicable to categorical data, wht if the data were continuous numerical data ?
#
# we set a threshold and try to find which where has the max information gain, tht will be regarded as the best split
#
# also the time complexity will be really very high if we have millions of records
